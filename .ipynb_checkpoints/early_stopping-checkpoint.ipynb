# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from pylab import rcParams
import matplotlib.pyplot as plt
import warnings
from mlxtend.plotting import plot_decision_regions
from matplotlib.colors import ListedColormap
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 7
#       5 import matplotlib.pyplot as plt
#       6 import warnings
# ----> 7 from mlxtend.plotting import plot_decision_regions
#       8 from matplotlib.colors import ListedColormap
#       9 from tensorflow.keras.models import Sequential
#
# File ~\anaconda3\Lib\site-packages\mlxtend\plotting\__init__.py:15
#      13 from .pca_correlation_graph import plot_pca_correlation_graph
#      14 from .plot_confusion_matrix import plot_confusion_matrix
# ---> 15 from .plot_linear_regression import plot_linear_regression
#      16 from .plot_sequential_feature_selection import plot_sequential_feature_selection
#      17 from .remove_chartjunk import remove_borders
#
# File ~\anaconda3\Lib\site-packages\mlxtend\plotting\plot_linear_regression.py:13
#      11 import numpy as np
#      12 from scipy.stats import pearsonr
# ---> 13 from sklearn.linear_model import LinearRegression
#      16 def plot_linear_regression(
#      17     X,
#      18     y,
#    (...)     24     xlim="auto",
#      25 ):
#      26     """Plot a linear regression line fit.
#      27
#      28     Parameters
#    (...)     62
#      63     """
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\__init__.py:10
#       1 """A variety of linear models."""
#       3 # Authors: The scikit-learn developers
#       4 # SPDX-License-Identifier: BSD-3-Clause
#       5
#       6 # See http://scikit-learn.sourceforge.net/modules/sgd.html and
#       7 # http://scikit-learn.sourceforge.net/modules/linear_model.html for
#       8 # complete documentation.
# ---> 10 from sklearn.linear_model._base import LinearRegression
#      11 from sklearn.linear_model._bayes import ARDRegression, BayesianRidge
#      12 from sklearn.linear_model._coordinate_descent import (
#      13     ElasticNet,
#      14     ElasticNetCV,
#    (...)     22     lasso_path,
#      23 )
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:24
#      15 from scipy.sparse.linalg import lsqr
#      17 from sklearn.base import (
#      18     BaseEstimator,
#      19     ClassifierMixin,
#    (...)     22     _fit_context,
#      23 )
# ---> 24 from sklearn.utils import _align_api_if_sparse, check_array, check_random_state
#      25 from sklearn.utils._array_api import (
#      26     _asarray_with_order,
#      27     _average,
#    (...)     34     supported_float_dtypes,
#      35 )
#      36 from sklearn.utils._param_validation import Interval
#
# ImportError: cannot import name '_align_api_if_sparse' from 'sklearn.utils' (C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\utils\__init__.py)

# %%
X, y = make_circles(n_samples=100, noise=0.1, random_state=1)

# %%
sns.scatterplot(X[:,0],X[:,1],hue=y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2)

# %%
model = Sequential()

model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=3500, verbose=0)

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(X_test, y_test.ravel(), clf = model, legend=2)
plt.show()

# %% [markdown]
# # Early Stopping

# %%
model = Sequential()

model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
callback = EarlyStopping(
    monitor="val_loss",
    min_delta=0.00001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False
)

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=3500, callbacks=callback)

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(X_test, y_test.ravel(), clf = model, legend=2)
plt.show()
